# %% [markdown]
# # K Means Clustering Project
#
# For this project we will attempt to use KMeans Clustering to cluster Universities into the two groups, Private and Public.
#
# ## The Data
#
# We will use a data frame with 777 observations on the following 18 variables.
# * Private: a factor with levels No and Yes indicating private or public university.
# * Apps: number of applications received.
# * Accept: number of applications accepted.
# * Enroll: number of new students enrolled.
# * Top10perc: pct. new students from top 10% of H.S. class.
# * Top25perc: pct. new students from top 25% of H.S. class.
# * F.Undergrad: number of fulltime undergraduates.
# * P.Undergrad: number of parttime undergraduates.
# * Outstate: out-of-state tuition.
# * Room.Board: room and board costs.
# * Books: estimated book costs.
# * Personal: estimated personal spending.
# * PhD: pct. of faculty with Ph.D.’s.
# * Terminal: pct. of faculty with terminal degree.
# * S.F.Ratio: student/faculty ratio.
# * perc.alumni pct. alumni who donate.
# * Expend: instructional expenditure per student.
# * Grad.Rate: graduation rate.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Get the Data

# %%
data = pd.read_csv('College_Data')
data.set_index(['Unnamed: 0'], inplace = True)
data.index.name = ''
data.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
#
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
#
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
# Private        777 non-null object
# Apps           777 non-null int64
# Accept         777 non-null int64
# Enroll         777 non-null int64
# Top10perc      777 non-null int64
# Top25perc      777 non-null int64
# F.Undergrad    777 non-null int64
# P.Undergrad    777 non-null int64
# Outstate       777 non-null int64
# Room.Board     777 non-null int64
# Books          777 non-null int64
# Personal       777 non-null int64
# PhD            777 non-null int64
# Terminal       777 non-null int64
# S.F.Ratio      777 non-null float64
# perc.alumni    777 non-null int64
# Expend         777 non-null int64
# Grad.Rate      777 non-null int64
# dtypes: float64(1), int64(16), object(1)
# memory usage: 115.3+ KB

# %%
data.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ## EDA

# %%
sns.set_style('whitegrid')
fig = plt.figure(figsize = (10,7))
sns.scatterplot(x = 'Room.Board', y = 'Grad.Rate', data = data, hue = 'Private')

# %% [markdown]
# Based off this plot: for lower Room/Board costs and Graduation rate dominate Public universities and vice versa.

# %%
fig = plt.figure(figsize = (10,7))
sns.scatterplot(x = 'Outstate', y = 'F.Undergrad', data = data, hue = 'Private')

# %% [markdown]
# Based off this plot: for lower Oustate and higher than about 2500 of full time undergraduates dominate Public universities and vice versa.

# %%
sns.set_style('whitegrid')
grid = sns.FacetGrid(data, hue = "Private", height = 5, aspect = 2, legend_out = True)
grid.map(plt.hist, "Outstate", bins = 20, alpha = 0.5)

# %% [markdown]
# Based off this histogram: for lower Outstate dominate Public universities and vice versa.

# %%
sns.set_style('whitegrid')
grid = sns.FacetGrid(data, hue = "Private", height = 5, aspect = 2)
grid.map(plt.hist, "Grad.Rate", bins = 20, alpha = 0.5)

# %% [markdown]
# Based off this histogram: higher graduation rate dominate in Private Universities and vice versa.

# %% [markdown]
# In this dataset seems to be a private school with a graduation rate of higher than 100%.

# %%
data[data['Grad.Rate']>100]
# Out:
#                   Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
#
# Cazenovia College     Yes  3847    3433     527          9         35
#
#                    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
#
# Cazenovia College         1010           12      9384        4840    600
#
#                    Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
#
# Cazenovia College       500   22        47       14.3           20    7697
#
#                    Grad.Rate
#
# Cazenovia College        118

# %% [markdown]
# Set that school's graduation rate to 100 so it makes sense.

# %%
data['Grad.Rate'] = data['Grad.Rate'].apply(lambda x: 100 if x > 100 else x)

# %%
data[data['Grad.Rate']>100]
# Out:
# Empty DataFrame
# Columns: [Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %%
sns.set_style('whitegrid')
grid = sns.FacetGrid(data, hue = "Private", height = 5, aspect = 2)
grid.map(plt.hist, "Grad.Rate", bins = 20, alpha = 0.5)

# %% [markdown]
# ## K Means Cluster Creation

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters = 2)
model.fit(data.drop('Private', axis = 1).dropna())
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# Cluster center vectors:

# %%
model.cluster_centers_
# Out:
# array([[1.81323468e+03, 1.28716592e+03, 4.91044843e+02, 2.53094170e+01,
#         5.34708520e+01, 2.18854858e+03, 5.95458894e+02, 1.03957085e+04,
#         4.31136472e+03, 5.41982063e+02, 1.28033632e+03, 7.04424514e+01,
#         7.78251121e+01, 1.40997010e+01, 2.31748879e+01, 8.93204634e+03,
#         6.50926756e+01],
#        [1.03631389e+04, 6.55089815e+03, 2.56972222e+03, 4.14907407e+01,
#         7.02037037e+01, 1.30619352e+04, 2.46486111e+03, 1.07191759e+04,
#         4.64347222e+03, 5.95212963e+02, 1.71420370e+03, 8.63981481e+01,
#         9.13333333e+01, 1.40277778e+01, 2.00740741e+01, 1.41705000e+04,
#         6.75925926e+01]])

# %% [markdown]
# ## Evaluation
#
# Check the results labels with actually results using confusion matrix and classification report.

# %%
data.dropna(inplace = True)
data['Cluster'] = model.labels_

# %%
data.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
#
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
#
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
#
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix

confusion_matrix(data['Private'].apply(lambda x: 1 if x == 'Yes' else 0), data['Cluster'])
# Out:
# array([[138,  74],
#        [531,  34]])

# %%
df1 = data['Private'].apply(lambda x: 1 if x == 'Yes' else 0)
classification_report(df1, data['Cluster'])
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.21      0.65      0.31       212\n           1       0.31      0.06      0.10       565\n\n    accuracy                           0.22       777\n   macro avg       0.26      0.36      0.21       777\nweighted avg       0.29      0.22      0.16       777\n'

# %% [markdown]
# Results are pretty good, because we just use features to cluster data.
